# %% [markdown]
# ## Pre-process all files

# %% [markdown]
# #### Imports

# %%
# !pip install uszipcode
# Out:
# Collecting uszipcode
#   Downloading uszipcode-1.0.1-py2.py3-none-any.whl (35 kB)
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from uszipcode) (23.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from uszipcode) (2.31.0)
# Collecting pathlib-mate (from uszipcode)
#   Downloading pathlib_mate-1.3.2-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 2.9 MB/s eta 0:00:00
# Collecting atomicwrites (from uszipcode)
#   Downloading atomicwrites-1.4.1.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Collecting fuzzywuzzy (from uszipcode)
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Collecting haversine>=2.5.0 (from uszipcode)
#   Downloading haversine-2.8.1-py2.py3-none-any.whl (7.7 kB)
# Requirement already satisfied: SQLAlchemy>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from uszipcode) (2.0.25)
# Collecting sqlalchemy-mate>=1.4.28.3 (from uszipcode)
#   Downloading sqlalchemy_mate-1.4.28.4-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 5.3 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.4.0->uszipcode) (4.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy>=1.4.0->uszipcode) (3.0.3)
# Collecting SQLAlchemy>=1.4.0 (from uszipcode)
#   Downloading SQLAlchemy-1.4.51-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 13.7 MB/s eta 0:00:00
# Requirement already satisfied: prettytable in /usr/local/lib/python3.10/dist-packages (from sqlalchemy-mate>=1.4.28.3->uszipcode) (3.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->uszipcode) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->uszipcode) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->uszipcode) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->uszipcode) (2024.2.2)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prettytable->sqlalchemy-mate>=1.4.28.3->uszipcode) (0.2.13)
# Building wheels for collected packages: atomicwrites
#   Building wheel for atomicwrites (setup.py) ... done
#   Created wheel for atomicwrites: filename=atomicwrites-1.4.1-py2.py3-none-any.whl size=6942 sha256=a6bdce12cbc91b4e0a8f7d8834ae92cc81d363bdda274f8fde41bed2c62054b5
#   Stored in directory: /root/.cache/pip/wheels/34/07/0b/33b15f68736109f72ea0bb2499521d87312b932620737447a2
# Successfully built atomicwrites
# Installing collected packages: fuzzywuzzy, SQLAlchemy, pathlib-mate, haversine, atomicwrites, sqlalchemy-mate, uszipcode
#   Attempting uninstall: SQLAlchemy
#     Found existing installation: SQLAlchemy 2.0.25
#     Uninstalling SQLAlchemy-2.0.25:
#       Successfully uninstalled SQLAlchemy-2.0.25
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython-sql 0.5.0 requires sqlalchemy>=2.0, but you have sqlalchemy 1.4.51 which is incompatible.
# Successfully installed SQLAlchemy-1.4.51 atomicwrites-1.4.1 fuzzywuzzy-0.18.0 haversine-2.8.1 pathlib-mate-1.3.2 sqlalchemy-mate-1.4.28.4 uszipcode-1.0.1

# %%
import pandas as pd
import numpy as np
import re
from uszipcode import SearchEngine

pd.set_option('display.max_rows', None)
# Out:
# /usr/local/lib/python3.10/dist-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# #### Some useful functions

# %%
def dataframe_to_csv(dataframe, output_file_name):
    """
    Writes the given DataFrame to a CSV file.

    Args:
    - dataframe: The pandas DataFrame to be written to a CSV file.
    - output_file_name: The name of the output CSV file. Include the path if you want to save it in a specific directory.

    Returns:
    - None
    """
    try:
        # Write the DataFrame to a CSV file
        dataframe.to_csv(output_file_name, index=False)
        print(f"DataFrame has been successfully written to {output_file_name}")
    except Exception as e:
        print(f"An error occurred while writing the DataFrame to a CSV file: {e}")

# %%
# Function to extract and split keywords
def split_keywords_vectorized(df, column_name):

    # Make a copy to avoid SettingWithCopyWarning if df is a slice from another DataFrame
    df = df.copy()

    # Extract numerical keywords
    df['numerical_keywords'] = df[column_name].str.findall(r'\b\d+\b').str.join(', ')

    # Extract alphabetical keywords and then filter by length
    df['alphabetical_keywords'] = df[column_name].str.findall(r'\b[a-zA-Z]+\b').str.join(', ')

    # Short alphabetical keywords (length ≤ 2)
    df['alphabetical_short_keywords'] = df['alphabetical_keywords'].apply(lambda x: ', '.join([word for word in x.split(', ') if len(word) <= 2]))

    # Long alphabetical keywords (length > 2)
    df['alphabetical_long_keywords'] = df['alphabetical_keywords'].apply(lambda x: ', '.join([word for word in x.split(', ') if len(word) > 2]))

    # Drop the temporary 'alphabetical_keywords' column
    df.drop(columns=['alphabetical_keywords'], inplace=True)

    return df

# %%
def add_space_before_suffix(address):
    # Define the pattern: a number (\d+) immediately followed by a street suffix
    pattern = r'(\d+)(RD|ND|ST|TH|rd|nd|st|th)'

    # Define the replacement pattern: the matched number and suffix separated by a space
    # \1 and \2 refer to the first and second captured groups in the pattern, respectively
    replacement = r'\1 \2'

    # Use re.sub() to search and replace the pattern in the address string
    modified_address = re.sub(pattern, replacement, address)

    return modified_address

# %%
def remove_rows_without_alphabets_or_numbers(df, address_column):
    # Use a regular expression to filter rows where the address column contains at least one alphabet character or number
    # The regular expression '[a-zA-Z0-9]' looks for any occurrence of any alphabet character or digit
    filtered_df = df[df[address_column].str.contains('[a-zA-Z0-9]', regex=True, na=False)]

    # Reset the index of the filtered DataFrame
    filtered_df.reset_index(drop=True, inplace=True)

    return filtered_df

# %% [markdown]
# #### Function that preprocess the files

# %%
def pre_process_all_files(path_1945, path_1975, path_1985):
  # Read the data
  df1945 = pd.read_csv(path_1945, low_memory=False)
  df1975 = pd.read_csv(path_1975, low_memory=False)
  df1985 = pd.read_csv(path_1985, low_memory=False)

  # Use dropna with how='all' to drop columns where all values are NaN
  dfc1945 = df1945.dropna(axis=1, how='all')
  dfc1975 = df1975.dropna(axis=1, how='all')
  dfc1985 = df1985.dropna(axis=1, how='all')

  # Make a copy of the dataframes
  dfc1945 = dfc1945.copy()
  dfc1975 = dfc1975.copy()
  dfc1985 = dfc1985.copy()

  # Convert the 'ADDRESS' column in each DataFrame to string
  dfc1945['ADDRESS'] = dfc1945['ADDRESS'].astype(str)
  dfc1975['ADDRESS'] = dfc1975['ADDRESS'].astype(str)
  dfc1985['ADDRESS'] = dfc1985['ADDRESS'].astype(str)

  # Append the year to the column names
  dfc1945.columns = [f"{col}_1945" for col in dfc1945.columns]
  dfc1975.columns = [f"{col}_1975" for col in dfc1975.columns]
  dfc1985.columns = [f"{col}_1985" for col in dfc1985.columns]

  return dfc1945, dfc1975, dfc1985

# %% [markdown]
# #### Apply the preprocess funtion

# %%
path_for_1945 = '/content/Lubbock - 1945 - 1945.csv'
path_for_1975 = '/content/Lubbock - 1975 - 1975.csv'
path_for_1985 = '/content/Lubbock - 1985 -  1985.csv'

df1945, df1975, df1985 = pre_process_all_files(path_for_1945, path_for_1975, path_for_1985)

# %% [markdown]
# ## Pre-Process 1945

# %% [markdown]
# #### Add a column to the df1945 dataframe to track the old index when updated

# %%
df1945 = df1945.copy()

# Add a new column to the 1945 dataframe
df1945['oldindex_1945'] = df1945.index

# %% [markdown]
# #### Function that process addresses with patterns

# %%
def process_addresses(dfc, pattern, dfn=None):
    """
    Processes addresses in a DataFrame using a specified regex pattern.

    Args:
    - dfc: DataFrame containing the original addresses.
    - pattern: Regex pattern to match addresses.
    - dfn: Optional DataFrame to append matched addresses. If None, a new DataFrame is created.

    Returns:
    - A tuple of DataFrames: (updated dfc without matched rows, dfn with appended matched rows).
    """

    # Convert the pattern to a compiled regex object if it's a string
    if isinstance(pattern, str):
        pattern = re.compile(pattern)

    # Check if dfn exists, otherwise initialize it
    if dfn is None:
        dfn_rows = []
    else:
        dfn_rows = dfn.to_dict('records')

    matched_indices = []  # Keep track of indices to remove from dfc

    for index, row in dfc.iterrows():
        match = pattern.match(row['ADDRESS_1945'])
        if match:
            keywords = ', '.join([group.strip() for group in match.groups() if group and group.strip()])
            new_row = row.to_dict()
            new_row['keywords_1945'] = keywords
            new_row['oldindex_1945'] = index

            dfn_rows.append(new_row)
            matched_indices.append(index)

    # Update dfn with the new rows
    dfn_updated = pd.DataFrame(dfn_rows)

    # Remove matched rows from dfc
    dfc_updated = dfc.drop(matched_indices).reset_index(drop=True)

    return dfc_updated, dfn_updated, len(matched_indices)

# %%
patterns_dict = {
    "pattern1": r'(\d{4})(\d{2})(ND|ST|TH|nd|st|th)(ST|st),([A-Za-z]+)',
    "pattern2": r'(\d{4})(N|S|E|W|n|s|e|w)(\d{2})(ND|ST|TH|nd|st|th)(ST|st),([A-Za-z]+)',
    "pattern3": r'(\d{4})(AVE|ave)([A-Za-z]),([A-Za-z]+)',
    "pattern4": r'(\d{3,4})(AVE|ave)([A-Za-z]),([A-Za-z]+)',
    "pattern5": r'(\d{4})(N|S|E|W|n|s|e|w)(MAIN|main)(ST|st),([A-Za-z]+)',
    "pattern6": r'(\d{3,4})(N|S|E|W|n|s|e|w)([A-Za-z]+)(AVE|ave),([A-Za-z]+)',
    "pattern7": r'(\d{3,4})([A-Za-z]+)(AVE|ave),([A-Za-z]+)',
    "pattern8": r'(\d{4})(\d{2})(RD|ND|ST|TH|rd|nd|st|th)(AVE|ave|ST|st),([A-Za-z]+)',
    "pattern9": r'(\d{4})(\d{3})(RD|ND|ST|TH|rd|nd|st|th)(AVE|ave|ST|st),([A-Za-z]+)',
    "pattern10": r'(\d{4})(MAIN|main)(AVE|ave|ST|st),([A-Za-z]+)',
    "pattern11": r'(\d{3,4})(N|S|E|W|n|s|e|w)(AVE|ave)([A-Za-z]),([A-Za-z]+)',
    "pattern12": r'(\d{3,4})(N|S|E|W|n|s|e|w)?(HARVARD|URSULINE|ERSKINE|FISHER|STANFORD|BROADWAY)(ST|st)?,([A-Za-z]+)',
    "pattern13": r'(\d{4})(N|S|E|W|n|s|e|w)?([A-Za-z]+)(\d+),([A-Za-z]+)'
}

# %%
def process_addresses_with_patterns(dfc, patterns_dict, dfn=None):
    total_matched_indices = 0

    # Initialize dfn if it does not exist
    if dfn is None:
        dfn = pd.DataFrame()

    for pattern_name, pattern_regex in patterns_dict.items():
        dfc, dfn, number_of_matched_indices = process_addresses(dfc, pattern_regex, dfn)
        total_matched_indices += number_of_matched_indices
        print(f'The number of matched indices for {pattern_name} is {number_of_matched_indices}')

    print(f'The total number of matched indices so far are {total_matched_indices}')
    return dfc, dfn, total_matched_indices

# %% [markdown]
# #### Apply the function to process the addresses

# %%
df1945_updated, dfn1945_updated, total_matched = process_addresses_with_patterns(df1945, patterns_dict)
# Out:
# The number of matched indices for pattern1 is 215
# The number of matched indices for pattern2 is 8
# The number of matched indices for pattern3 is 33
# The number of matched indices for pattern4 is 6
# The number of matched indices for pattern5 is 3
# The number of matched indices for pattern6 is 23
# The number of matched indices for pattern7 is 48
# The number of matched indices for pattern8 is 14
# The number of matched indices for pattern9 is 6
# The number of matched indices for pattern10 is 5
# The number of matched indices for pattern11 is 3
# The number of matched indices for pattern12 is 12
# The number of matched indices for pattern13 is 6
# The total number of matched indices so far are 382

# %% [markdown]
# #### Expanding the short forms in the dataframe like Lub -> Lubbock, Bx -> Box and more

# %%
dfn1945_updated
# Out:
#     People_1945  document number_1945  PARCEL NUMBER_1945  \
# 0         Aoxue                   NaN                 NaN
# 1           NaN                   NaN                 NaN
# 2           NaN                   NaN                 NaN
# 3           NaN                   NaN                 NaN
# 4           NaN                   NaN                 NaN
# 5           NaN                   NaN                 NaN
# 6           NaN                   NaN                 NaN
# 7           NaN                   NaN                 NaN
# 8           NaN                   NaN                 NaN
# 9           NaN                   NaN                 NaN
# 10          NaN                   NaN                 NaN
# 11          NaN                   NaN                 NaN
# 12          NaN                   NaN                 NaN
# 13          NaN                   NaN                 NaN
# 14          NaN                   NaN                 NaN
# 15          NaN                   NaN                 NaN
# 16          NaN                   NaN                 NaN
# 17          NaN                   NaN                 NaN
# 18          NaN                   NaN                 NaN
# 19          NaN                   NaN                 NaN
# 20          NaN                   NaN                 NaN
# 21          NaN                   NaN                 NaN
# 22          NaN                   NaN                 NaN
# 23          NaN                   NaN                 NaN
# 24          NaN                   NaN                 NaN
# 25          NaN                   NaN                 NaN
# 26          NaN                   NaN                 NaN
# 27          NaN                   NaN                 NaN
# 28          NaN                   NaN                 NaN
# 29          NaN                   NaN                 NaN
# 30          NaN                   NaN                 NaN
# 31          NaN                   NaN                 NaN
# 32          NaN                   NaN                 NaN
# 33          NaN                   NaN                 NaN
# 34          NaN                   NaN                 NaN
# 35          NaN                   NaN                 NaN
# 36          NaN                   NaN                 NaN
# 37          NaN                   NaN                 NaN
# 38          NaN                   NaN                 NaN
# 39          NaN                   NaN                 NaN
# 40          NaN                   NaN                 NaN
# 41          NaN                   NaN                 NaN
# 42          NaN                   NaN                 NaN
# 43          NaN                   NaN                 NaN
# 44          NaN                   NaN                 NaN
# 45          NaN                   NaN                 NaN
# 46          NaN                   NaN                 NaN
# 47          NaN                   NaN                 NaN
# 48          NaN                   NaN                 NaN
# 49          NaN                   NaN                 NaN
# 50          NaN                   NaN                 NaN
# 51          NaN                   NaN                 NaN
# 52          NaN                   NaN                 NaN
# 53          NaN                   NaN                 NaN
# 54          NaN                   NaN                 NaN
# 55          NaN                   NaN                 NaN
# 56          NaN                   NaN                 NaN
# 57          NaN                   NaN                 NaN
# 58          NaN                   NaN                 NaN
# 59          NaN                   NaN                 NaN
# 60          NaN                   NaN                 NaN
# 61          NaN                   NaN                 NaN
# 62          NaN                   NaN                 NaN
# 63          NaN                   NaN                 NaN
# 64          NaN                   NaN                 NaN
# 65          NaN                   NaN                 NaN
# 66          NaN                   NaN                 NaN
# 67          NaN                   NaN                 NaN
# 68          NaN                   NaN                 NaN
# 69          NaN                   NaN                 NaN
# 70          NaN                   NaN                 NaN
# 71          NaN                   NaN                 NaN
# 72          NaN                   NaN                 NaN
# 73          NaN                   NaN                 NaN
# 74          NaN                   NaN                 NaN
# 75          NaN                   NaN                 NaN
# 76          NaN                   NaN                 NaN
# 77          NaN                   NaN                 NaN
# 78          NaN                   NaN                 NaN
# 79          NaN                   NaN                 NaN
# 80          NaN                   NaN                 NaN
# 81          NaN                   NaN                 NaN
# 82          NaN                   NaN                 NaN
# 83          NaN                   NaN                 NaN
# 84          NaN                   NaN                 NaN
# 85          NaN                   NaN                 NaN
# 86          NaN                   NaN                 NaN
# 87          NaN                   NaN                 NaN
# 88          NaN                   NaN                 NaN
# 89          NaN                   NaN                 NaN
# 90          NaN                   NaN                 NaN
# 91          NaN                   NaN                 NaN
# 92          NaN                   NaN                 NaN
# 93          NaN                   NaN                 NaN
# 94          NaN                   NaN                 NaN
# 95          NaN                   NaN                 NaN
# 96          NaN                   NaN                 NaN
# 97          NaN                   NaN                 NaN
# 98          NaN                   NaN                 NaN
# 99          NaN                   NaN                 NaN
# 100         NaN                   NaN                 NaN
# 101         NaN                   NaN                 NaN
# 102         NaN                   NaN                 NaN
# 103         NaN                   NaN                 NaN
# 104         NaN                   NaN                 NaN
# 105         NaN                   NaN                 NaN
# 106         NaN                   NaN                 NaN
# 107         NaN                   NaN                 NaN
# 108         NaN                   NaN                 NaN
# 109         NaN                   NaN                 NaN
# 110         NaN                   NaN                 NaN
# 111         NaN                   NaN                 NaN
# 112         NaN                   NaN                 NaN
# 113         NaN                   NaN                 NaN
# 114         NaN                   NaN                 NaN
# 115         NaN                   NaN                 NaN
# 116         NaN                   NaN                 NaN
# 117         NaN                   NaN                 NaN
# 118         NaN                   NaN                 NaN
# 119         NaN                   NaN                 NaN
# 120         NaN                   NaN                 NaN
# 121         NaN                   NaN                 NaN
# 122         NaN                   NaN                 NaN
# 123         NaN                   NaN                 NaN
# 124         NaN                   NaN                 NaN
# 125         NaN                   NaN                 NaN
# 126         NaN                   NaN                 NaN
# 127         NaN                   NaN                 NaN
# 128         NaN                   NaN                 NaN
# 129         NaN                   NaN                 NaN
# 130         NaN                   NaN                 NaN
# 131         NaN                   NaN                 NaN
# 132         NaN                   NaN                 NaN
# 133         NaN                   NaN                 NaN
# 134         NaN                   NaN                 NaN
# 135         NaN                   NaN                 NaN
# 136         NaN                   NaN                 NaN
# 137         NaN                   NaN                 NaN
# 138         NaN                   NaN                 NaN
# 139         NaN                   NaN                 NaN
# 140         NaN                   NaN                 NaN
# 141         NaN                   NaN                 NaN
# 142         NaN                   NaN                 NaN
# 143         NaN                   NaN                 NaN
# 144         NaN                   NaN                 NaN
# 145         NaN                   NaN                 NaN
# 146         NaN                   NaN                 NaN
# 147         NaN                   NaN                 NaN
# 148         NaN                   NaN                 NaN
# 149         NaN                   NaN                 NaN
# 150         NaN                   NaN                 NaN
# 151         NaN                   NaN                 NaN
# 152         NaN                   NaN                 NaN
# 153         NaN                   NaN                 NaN
# 154         NaN                   NaN                 NaN
# 155         NaN                   NaN                 NaN
# 156         NaN                   NaN                 NaN
# 157         NaN                   NaN                 NaN
# 158         NaN                   NaN                 NaN
# 159         NaN                   NaN                 NaN
# 160         NaN                   NaN                 NaN
# 161         NaN                   NaN                 NaN
# 162         NaN                   NaN                 NaN
# 163         NaN                   NaN                 NaN
# 164         NaN                   NaN                 NaN
# 165         NaN                   NaN                 NaN
# 166         NaN                   NaN                 NaN
# 167         NaN                   NaN                 NaN
# 168         NaN                   NaN                 NaN
# 169         NaN                   NaN                 NaN
# 170         NaN                   NaN                 NaN
# 171         NaN                   NaN                 NaN
# 172         NaN                   NaN                 NaN
# 173         NaN                   NaN                 NaN
# 174         NaN                   NaN                 NaN
# 175         NaN                   NaN                 NaN
# 176         NaN                   NaN                 NaN
# 177         NaN                   NaN                 NaN
# 178         NaN                   NaN                 NaN
# 179         NaN                   NaN                 NaN
# 180         NaN                   NaN                 NaN
# 181         NaN                   NaN                 NaN
# 182         NaN                   NaN                 NaN
# 183         NaN                   NaN                 NaN
# 184         NaN                   NaN                 NaN
# 185         NaN                   NaN                 NaN
# 186         NaN                   NaN                 NaN
# 187         NaN                   NaN                 NaN
# 188         NaN                   NaN                 NaN
# 189         NaN                   NaN                 NaN
# 190         NaN                   NaN                 NaN
# 191         NaN                   NaN                 NaN
# 192         NaN                   NaN                 NaN
# 193         NaN                   NaN                 NaN
# 194         NaN                   NaN                 NaN
# 195         NaN                   NaN                 NaN
# 196         NaN                   NaN                 NaN
# 197         NaN                   NaN                 NaN
# 198         NaN                   NaN                 NaN
# 199         NaN                   NaN                 NaN
# 200         NaN                   NaN                 NaN
# 201         NaN                   NaN                 NaN
# 202         NaN                   NaN                 NaN
# 203         NaN                   NaN                 NaN
# 204         NaN                   NaN                 NaN
# 205         NaN                   NaN                 NaN
# 206         NaN                   NaN                 NaN
# 207         NaN                   NaN                 NaN
# 208         NaN                   NaN                 NaN
# 209         NaN                   NaN                 NaN
# 210         NaN                   NaN                 NaN
# 211         NaN                   NaN                 NaN
# 212         NaN                   NaN                 NaN
# 213         NaN                   NaN                 NaN
# 214         NaN                   NaN                 NaN
# 215         NaN                   NaN                 NaN
# 216         NaN                   NaN                 NaN
# 217         NaN                   NaN                 NaN
# 218         NaN                   NaN                 NaN
# 219         NaN                   NaN                 NaN
# 220         NaN                   NaN                 NaN
# 221         NaN                   NaN                 NaN
# 222         NaN                   NaN                 NaN
# 223         NaN                   NaN                 NaN
# 224         NaN                   NaN                 NaN
# 225         NaN                   NaN                 NaN
# 226         NaN                   NaN                 NaN
# 227         NaN                   NaN                 NaN
# 228         NaN                   NaN                 NaN
# 229         NaN                   NaN                 NaN
# 230         NaN                   NaN                 NaN
# 231         NaN                   NaN                 NaN
# 232         NaN                   NaN                 NaN
# 233         NaN                   NaN                 NaN
# 234         NaN                   NaN                 NaN
# 235         NaN                   NaN                 NaN
# 236         NaN                   NaN                 NaN
# 237         NaN                   NaN                 NaN
# 238         NaN                   NaN                 NaN
# 239         NaN                   NaN                 NaN
# 240         NaN                   NaN                 NaN
# 241         NaN                   NaN                 NaN
# 242         NaN                   NaN                 NaN
# 243         NaN                   NaN                 NaN
# 244         NaN                   NaN                 NaN
# 245         NaN                   NaN                 NaN
# 246         NaN                   NaN                 NaN
# 247         NaN                   NaN                 NaN
# 248         NaN                   NaN                 NaN
# 249         NaN                   NaN                 NaN
# 250         NaN                   NaN                 NaN
# 251         NaN                   NaN                 NaN
# 252         NaN                   NaN                 NaN
# 253         NaN                   NaN                 NaN
# 254         NaN                   NaN                 NaN
# 255         NaN                   NaN                 NaN
# 256         NaN                   NaN                 NaN
# 257         NaN                   NaN                 NaN
# 258         NaN                   NaN                 NaN
# 259         NaN                   NaN                 NaN
# 260         NaN                   NaN                 NaN
# 261         NaN                   NaN                 NaN
# 262         NaN                   NaN                 NaN
# 263         NaN                   NaN                 NaN
# 264         NaN                   NaN                 NaN
# 265         NaN                   NaN                 NaN
# 266         NaN                   NaN                 NaN
# 267         NaN                   NaN                 NaN
# 268         NaN                   NaN                 NaN
# 269         NaN                   NaN                 NaN
# 270         NaN                   NaN                 NaN
# 271         NaN                   NaN                 NaN
# 272         NaN                   NaN                 NaN
# 273         NaN                   NaN                 NaN
# 274         NaN                   NaN                 NaN
# 275         NaN                   NaN                 NaN
# 276         NaN                   NaN                 NaN
# 277         NaN                   NaN                 NaN
# 278         NaN                   NaN                 NaN
# 279         NaN                   NaN                 NaN
# 280         NaN                   NaN                 NaN
# 281         NaN                   NaN                 NaN
# 282         NaN                   NaN                 NaN
# 283         NaN                   NaN                 NaN
# 284         NaN                   NaN                 NaN
# 285         NaN                   NaN                 NaN
# 286         NaN                   NaN                 NaN
# 287         NaN                   NaN                 NaN
# 288         NaN                   NaN                 NaN
# 289         NaN                   NaN                 NaN
# 290         NaN                   NaN                 NaN
# 291         NaN                   NaN                 NaN
# 292         NaN                   NaN                 NaN
# 293         NaN                   NaN                 NaN
# 294         NaN                   NaN                 NaN
# 295         NaN                   NaN                 NaN
# 296         NaN                   NaN                 NaN
# 297         NaN                   NaN                 NaN
# 298         NaN                   NaN                 NaN
# 299         NaN                   NaN                 NaN
# 300         NaN                   NaN                 NaN
# 301         NaN                   NaN                 NaN
# 302         NaN                   NaN                 NaN
# 303         NaN                   NaN                 NaN
# 304         NaN                   NaN                 NaN
# 305         NaN                   NaN                 NaN
# 306         NaN                   NaN                 NaN
# 307         NaN                   NaN                 NaN
# 308         NaN                   NaN                 NaN
# 309         NaN                   NaN                 NaN
# 310         NaN                   NaN                 NaN
# 311         NaN                   NaN                 NaN
# 312         NaN                   NaN                 NaN
# 313         NaN                   NaN                 NaN
# 314         NaN                   NaN                 NaN
# 315         NaN                   NaN                 NaN
# 316         NaN                   NaN                 NaN
# 317         NaN                   NaN                 NaN
# 318         NaN                   NaN                 NaN
# 319         NaN                   NaN                 NaN
# 320         NaN                   NaN                 NaN
# 321         NaN                   NaN                 NaN
# 322         NaN                   NaN                 NaN
# 323         NaN                   NaN                 NaN
# 324         NaN                   NaN                 NaN
# 325         NaN                   NaN                 NaN
# 326         NaN                   NaN                 NaN
# 327         NaN                   NaN                 NaN
# 328         NaN                   NaN                 NaN
# 329         NaN                   NaN                 NaN
# 330         NaN                   NaN                 NaN
# 331         NaN                   NaN                 NaN
# 332         NaN                   NaN                 NaN
# 333         NaN                   NaN                 NaN
# 334         NaN                   NaN                 NaN
# 335         NaN                   NaN                 NaN
# 336         NaN                   NaN                 NaN
# 337         NaN                   NaN                 NaN
# 338         NaN                   NaN                 NaN
# 339         NaN                   NaN                 NaN
# 340         NaN                   NaN                 NaN
# 341         NaN                   NaN                 NaN
# 342         NaN                   NaN                 NaN
# 343         NaN                   NaN                 NaN
# 344         NaN                   NaN                 NaN
# 345         NaN                   NaN                 NaN
# 346         NaN                   NaN                 NaN
# 347         NaN                   NaN                 NaN
# 348         NaN                   NaN                 NaN
# 349         NaN                   NaN                 NaN
# 350         NaN                   NaN                 NaN
# 351         NaN                   NaN                 NaN
# 352         NaN                   NaN                 NaN
# 353         NaN                   NaN                 NaN
# 354         NaN                   NaN                 NaN
# 355         NaN                   NaN                 NaN
# 356         NaN                   NaN                 NaN
# 357         NaN                   NaN                 NaN
# 358         NaN                   NaN                 NaN
# 359         NaN                   NaN                 NaN
# 360         NaN                   NaN                 NaN
# 361         NaN                   NaN                 NaN
# 362         NaN                   NaN                 NaN
# 363         NaN                   NaN                 NaN
# 364         NaN                   NaN                 NaN
# 365         NaN                   NaN                 NaN
# 366         NaN                   NaN                 NaN
# 367         NaN                   NaN                 NaN
# 368         NaN                   NaN                 NaN
# 369         NaN                   NaN                 NaN
# 370         NaN                   NaN                 NaN
# 371         NaN                   NaN                 NaN
# 372         NaN                   NaN                 NaN
# 373         NaN                   NaN                 NaN
# 374         NaN                   NaN                 NaN
# 375         NaN                   NaN                 NaN
# 376         NaN                   NaN                 NaN
# 377         NaN                   NaN                 NaN
# 378         NaN                   NaN                 NaN
# 379         NaN                   NaN                 NaN
# 380         NaN                   NaN                 NaN
# 381         NaN                   NaN                 NaN
#
#                     ADDRESS_1945  ORIGINAL GRANTEE CITY OR TOWN_1945  \
# 0             240722NDST,LUBBOCK                                 NaN
# 1             280828THST,LUBBOCK                                 NaN
# 2             231631STST,LUBBOCK                                 NaN
# 3             191327THST,LUBBOCK                                 NaN
# 4             210215THST,LUBBOCK                                 NaN
# 5             230629THST,LUBBOCK                                 NaN
# 6             221260THST,LUBBOCK                                 NaN
# 7             290520THST,LUBBOCK                                 NaN
# 8             152327THST,LUBBOCK                                 NaN
# 9             201188THST,LUBBOCK                                 NaN
# 10            300522NDST,LUBBOCK                                 NaN
# 11            191416THST,LUBBOCK                                 NaN
# 12            191216THST,LUBBOCK                                 NaN
# 13            191861STST,LUBBOCK                                 NaN
# 14            162210THST,LUBBOCK                                 NaN
# 15            221560THST,LUBBOCK                                 NaN
# 16            151529THST,LUBBOCK                                 NaN
# 17            222217THST,LUBBOCK                                 NaN
# 18            260824THST,LUBBOCK                                 NaN
# 19            201917THST,LUBBOCK                                 NaN
# 20            210127THST,LUBBOCK                                 NaN
# 21            242826THST,LUBBOCK                                 NaN
# 22            210715THST,LUBBOCK                                 NaN
# 23            211762NDST,LUBBOCK                                 NaN
# 24            240813THST,LUBBOCK                                 NaN
# 25            211918THST,LUBBOCK                                 NaN
# 26            240813THST,LUBBOCK                                 NaN
# 27            172024THST,LUBBOCK                                 NaN
# 28            190615THST,LUBBOCK                                 NaN
# 29            212420THST,LUBBOCK                                 NaN
# 30            221117THST,LUBBOCK                                 NaN
# 31            261321STST,LUBBOCK                                 NaN
# 32            190925THST,LUBBOCK                                 NaN
# 33            270121STST,LUBBOCK                                 NaN
# 34            270121STST,LUBBOCK                                 NaN
# 35            270121STST,LUBBOCK                                 NaN
# 36            143878THST,LUBBOCK                                 NaN
# 37            190929THST,LUBBOCK                                 NaN
# 38            130530THST,LUBBOCK                                 NaN
# 39            132016THST,LUBBOCK                                 NaN
# 40            151331STST,LUBBOCK                                 NaN
# 41            213819THST,LUBBOCK                                 NaN
# 42            222019THST,LUBBOCK                                 NaN
# 43            281526THST,LUBBOCK                                 NaN
# 44            131525THST,LUBBOCK                                 NaN
# 45            132225THST,LUBBOCK                                 NaN
# 46            131028THST,LUBBOCK                                 NaN
# 47            190694THST,LUBBOCK                                 NaN
# 48            161939THST,LUBBOCK                                 NaN
# 49            210116THST,LUBBOCK                                 NaN
# 50            280327THST,LUBBOCK                                 NaN
# 51            221114THST,LUBBOCK                                 NaN
# 52            270129THST,LUBBOCK                                 NaN
# 53            220329THST,LUBBOCK                                 NaN
# 54            311721STST,LUBBOCK                                 NaN
# 55            241221STST,LUBBOCK                                 NaN
# 56            221996THST,LUBBOCK                                 NaN
# 57            240129THST,LUBBOCK                                 NaN
# 58            240632NDST,LUBBOCK                                 NaN
# 59            151928THST,LUBBOCK                                 NaN
# 60            230328THST,LUBBOCK                                 NaN
# 61            211730THST,LUBBOCK                                 NaN
# 62            220325THST,LUBBOCK                                 NaN
# 63            212130THST,LUBBOCK                                 NaN
# 64            220525THST,LUBBOCK                                 NaN
# 65            220525THST,LUBBOCK                                 NaN
# 66            130527THST,LUBBOCK                                 NaN
# 67            201417THST,LUBBOCK                                 NaN
# 68            152427THST,LUBBOCK                                 NaN
# 69            161719THST,LUBBOCK                                 NaN
# 70            191820THST,LUBBOCK                                 NaN
# 71            150625THST,LUBBOCK                                 NaN
# 72            241032NDST,LUBBOCK                                 NaN
# 73            112131STST,LUBBOCK                                 NaN
# 74            192316THST,LUBBOCK                                 NaN
# 75            192316THST,LUBBOCK                                 NaN
# 76            151830THST,LUBBOCK                                 NaN
# 77            170924THST,LUBBOCK                                 NaN
# 78            310422NDST,LUBBOCK                                 NaN
# 79            242229THST,LUBBOCK                                 NaN
# 80            151727THST,LUBBOCK                                 NaN
# 81            231630THST,LUBBOCK                                 NaN
# 82            240431STST,LUBBOCK                                 NaN
# 83            192416THST,LUBBOCK                                 NaN
# 84            192416THST,LUBBOCK                                 NaN
# 85            130326THST,LUBBOCK                                 NaN
# 86            220217THST,LUBBOCK                                 NaN
# 87            263024THST,LUBBOCK                                 NaN
# 88            242332NDST,LUBBOCK                                 NaN
# 89            192521STST,LUBBOCK                                 NaN
# 90            201916THST,LUBBOCK                                 NaN
# 91            243222NDST,LUBBOCK                                 NaN
# 92            251629THST,LUBBOCK                                 NaN
# 93            151326THST,LUBBOCK                                 NaN
# 94            250826THST,LUBBOCK                                 NaN
# 95            251128THST,LUBBOCK                                 NaN
# 96            232290THST,LUBBOCK                                 NaN
# 97            251122NDST,LUBBOCK                                 NaN
# 98            262621STST,LUBBOCK                                 NaN
# 99            141124THST,LUBBOCK                                 NaN
# 100           131226THST,LUBBOCK                                 NaN
# 101           130826THST,LUBBOCK                                 NaN
# 102           261322NDST,LUBBOCK                                 NaN
# 103           220616THST,LUBBOCK                                 NaN
# 104           182279THST,LUBBOCK                                 NaN
# 105           280130THST,LUBBOCK                                 NaN
# 106           151127THST,LUBBOCK                                 NaN
# 107           181113THST,LUBBOCK                                 NaN
# 108           212225THST,LUBBOCK                                 NaN
# 109           191818THST,LUBBOCK                                 NaN
# 110           231416THST,LUBBOCK                                 NaN
# 111           262721STST,LUBBOCK                                 NaN
# 112           191999THST,LUBBOCK                                 NaN
# 113           252221STST,LUBBOCK                                 NaN
# 114           140724THST,LUBBOCK                                 NaN
# 115           191081STST,LUBBOCK                                 NaN
# 116           280128THST,LUBBOCK                                 NaN
# 117           192081STST,LUBBOCK                                 NaN
# 118           152124THST,LUBBOCK                                 NaN
# 119           152124THST,LUBBOCK                                 NaN
# 120           150522NDST,LUBBOCK                                 NaN
# 121           241226THST,LUBBOCK                                 NaN
# 122           270622NDST,LUBBOCK                                 NaN
# 123           201716THST,LUBBOCK                                 NaN
# 124           150828THST,LUBBOCK                                 NaN
# 125           281022NDST,LUBBOCK                                 NaN
# 126           281420THST,LUBBOCK                                 NaN
# 127           201031STST,LUBBOCK                                 NaN
# 128           201031STST,LUBBOCK                                 NaN
# 129           231188THST,LUBBOCK                                 NaN
# 130           222020THST,LUBBOCK                                 NaN
# 131           211729THST,LUBBOCK                                 NaN
# 132           282624THST,LUBBOCK                                 NaN
# 133           251425THST,LUBBOCK                                 NaN
# 134           242321STST,LUBBOCK                                 NaN
# 135           262321STST,LUBBOCK                                 NaN
# 136           282024THST,LUBBOCK                                 NaN
# 137           211520THST,LUBBOCK                                 NaN
# 138           211520THST,LUBBOCK                                 NaN
# 139           270930THST,LUBBOCK                                 NaN
# 140           150227THST,LUBBOCK                                 NaN
# 141           200127THST,LUBBOCK                                 NaN
# 142           270530THST,LUBBOCK                                 NaN
# 143           232278THST,LUBBOCK                                 NaN
# 144           221125THST,LUBBOCK                                 NaN
# 145           200627THST,LUBBOCK                                 NaN
# 146           201027THST,LUBBOCK                                 NaN
# 147           151226THST,LUBBOCK                                 NaN
# 148           210230THST,LUBBOCK                                 NaN
# 149           131327THST,LUBBOCK                                 NaN
# 150           242227THST,LUBBOCK                                 NaN
# 151           200825THST,LUBBOCK                                 NaN
# 152           200825THST,LUBBOCK                                 NaN
# 153           162568THST,LUBBOCK                                 NaN
# 154           331120THST,LUBBOCK                                 NaN
# 155           231717THST,LUBBOCK                                 NaN
# 156           180113THST,LUBBOCK                                 NaN
# 157           321821STST,LUBBOCK                                 NaN
# 158           150325THST,LUBBOCK                                 NaN
# 159           211514THST,LUBBOCK                                 NaN
# 160            231880THST,LUBBOC                                 NaN
# 161           210322NDST,LUBBOCK                                 NaN
# 162           261122NDST,LUBBOCK                                 NaN
# 163           192124THST,LUBBOCK                                 NaN
# 164           231129THST,LUBBOCK                                 NaN
# 165           231120THST,LUBBOCK                                 NaN
# 166           242221STST,LUBBOCK                                 NaN
# 167           190627THST,LUBBOCK                                 NaN
# 168           230220THST,LUBBOCK                                 NaN
# 169           230220THST,LUBBOCK                                 NaN
# 170           191126THST,LUBBOCK                                 NaN
# 171           161817THST,LUBBOCK                                 NaN
# 172           161917THST,LUBBOCK                                 NaN
# 173           212326THST,LUBBOCK                                 NaN
# 174           250921STST,LUBBOCK                                 NaN
# 175           230921STST,LUBBOCK                                 NaN
# 176           150932NDST,LUBBOCK                                 NaN
# 177           192224THST,LUBBOCK                                 NaN
# 178           321421STST,LUBBOCK                                 NaN
# 179           220615THST,LUBBOCK                                 NaN
# 180           211531STST,LUBBOCK                                 NaN
# 181           201615THST,LUBBOCK                                 NaN
# 182           252020THST,LUBBOCK                                 NaN
# 183           243628THST,LUBBOCK                                 NaN
# 184           210631STST,LUBBOCK                                 NaN
# 185           251524THST,LUBBOCK                                 NaN
# 186           230538THST,LUBBOCK                                 NaN
# 187           121513THST,LUBBOCK                                 NaN
# 188           201615THST,LUBBOCK                                 NaN
# 189           201615THST,LUBBOCK                                 NaN
# 190           171521STST,LUBBOCK                                 NaN
# 191           271230THST,LUBBOCK                                 NaN
# 192           271230THST,LUBBOCK                                 NaN
# 193           190625THST,LUBBOCK                                 NaN
# 194           211622NDST,LUBBOCK                                 NaN
# 195           211622NDST,LUBBOCK                                 NaN
# 196           211510THST,LUBBOCK                                 NaN
# 197           231220THST,LUBBOCK                                 NaN
# 198           211427THST,LUBBOCK                                 NaN
# 199           202115THST,LUBBOCK                                 NaN
# 200           302220THST,LUBBOCK                                 NaN
# 201           222127THST,LUBBOCK                                 NaN
# 202           210320THST,LUBBOCK                                 NaN
# 203           251420THST,LUBBOCK                                 NaN
# 204           260630THST,LUBBOCK                                 NaN
# 205           260630THST,LUBBOCK                                 NaN
# 206           151513THST,LUBBOCK                                 NaN
# 207           130926THST,LUBBOCK                                 NaN
# 208           243621STST,LUBBOCK                                 NaN
# 209           161122NDST,LUBBOCK                                 NaN
# 210           331122NDST,LUBBOCK                                 NaN
# 211           231330THST,LUBBOCK                                 NaN
# 212           231330THST,LUBBOCK                                 NaN
# 213           161970THST,LUBBOCK                                 NaN
# 214           110113THST,LUBBOCK                                 NaN
# 215          2808E16THST,LUBBOCK                                 NaN
# 216          2019E47THST,LUBBOCK                                 NaN
# 217          2015E14THST,LUBBOCK                                 NaN
# 218          2208E16THST,LUBBOCK                                 NaN
# 219          2421E30THST,LUBBOCK                                 NaN
# 220        1601N15THST,WOLFFORTH                                 NaN
# 221          2417E28THST,LUBBOCK                                 NaN
# 222          2417E28THST,LUBBOCK                                 NaN
# 223             1502AVEJ,LUBBOCK                                 NaN
# 224             2006AVEK,LUBBOCK                                 NaN
# 225             1915AVEM,LUBBOCK                                 NaN
# 226             1925AVEP,LUBBOCK                                 NaN
# 227             1814AVEQ,LUBBOCK                                 NaN
# 228             2201AVEJ,LUBBOCK                                 NaN
# 229             1916AVEM,LUBBOCK                                 NaN
# 230             1302AVEE,LUBBOCK                                 NaN
# 231             1312AVEJ,LUBBOCK                                 NaN
# 232             1312AVEJ,LUBBOCK                                 NaN
# 233             1509AVEK,LUBBOCK                                 NaN
# 234             1908AVER,LUBBOCK                                 NaN
# 235             1716AVEE,LUBBOCK                                 NaN
# 236             2108AVEP,LUBBOCK                                 NaN
# 237             1948AVEN,LUBBOCK                                 NaN
# 238             2113AVEM,LUBBOCK                                 NaN
# 239             1511AVEO,LUBBOCK                                 NaN
# 240             2007AVEJ,LUBBOCK                                 NaN
# 241             1917AVEO,LUBBOCK                                 NaN
# 242             2601AVEK,LUBBOCK                                 NaN
# 243             1927AVEN,LUBBOCK                                 NaN
# 244             1314AVEK,LUBBOCK                                 NaN
# 245             1212AVEJ,LUBBOCK                                 NaN
# 246             1002AVEF,LUBBOCK                                 NaN
# 247             1608AVEN,LUBBOCK                                 NaN
# 248             1309AVEL,LUBBOCK                                 NaN
# 249             1313AVEJ,LUBBOCK                                 NaN
# 250             1810AVEM,LUBBOCK                                 NaN
# 251             1220AVEK,LUBBOCK                                 NaN
# 252             1220AVEK,LUBBOCK                                 NaN
# 253             1806AVER,LUBBOCK                                 NaN
# 254             1806AVER,LUBBOCK                                 NaN
# 255             2013AVEJ,LUBBOCK                                 NaN
# 256              903AVEK,LUBBOCK                                 NaN
# 257              809AVEG,LUBBOCK                                 NaN
# 258              912AVEB,LUBBOCK                                 NaN
# 259              918AVEJ,LUBBOCK                                 NaN
# 260              812AVEG,LUBBOCK                                 NaN
# 261              808AVEG,LUBBOCK                                 NaN
# 262          2216EMAINST,LUBBOCK                                 NaN
# 263          2221EMAINST,LUBBOCK                                 NaN
# 264          1519EMAINST,LUBBOCK                                 NaN
# 265       1710NORWICHAVE,LUBBOCK                                 NaN
# 266         419NOLIVEAVE,LUBBOCK                                 NaN
# 267           2205ELMAVE,LUBBOCK                                 NaN
# 268     809NFRANKFORDAVE,LUBBOCK                                 NaN
# 269         408NXENIAAVE,LUBBOCK                                 NaN
# 270         1209ELMAVE,WOLFFORTH                                 NaN
# 271        1913NGENOAAVE,LUBBOCK                                 NaN
# 272       814NBELMONTAVE,LUBBOCK                                 NaN
# 273            602ELMAVE,LUBBOCK                                 NaN
# 274        612NBANGORAVE,LUBBOCK                                 NaN
# 275      1304NQUINTONAVE,LUBBOCK                                 NaN
# 276      1304NQUINTONAVE,LUBBOCK                                 NaN
# 277      1304NQUINTONAVE,LUBBOCK                                 NaN
# 278       708NCHICAGOAVE,LUBBOCK                                 NaN
# 279       708NCHICAGOAVE,LUBBOCK                                 NaN
# 280        1712NGENOAAVE,LUBBOCK                                 NaN
# 281       1701NORWICHAVE,LUBBOCK                                 NaN
# 282        1912NGENOAAVE,LUBBOCK                                 NaN
# 283     602NENGLEWOODAVE,LUBBOCK                                 NaN
# 284         524NDOVERAVE,LUBBOCK                                 NaN
# 285       503NCHICAGOAVE,LUBBOCK                                 NaN
# 286     702NENGLEWOODAVE,LUBBOCK                                 NaN
# 287        902NBANGORAVE,LUBBOCK                                 NaN
# 288     417BUDDYHOLLYAVE,LUBBOCK                                 NaN
# 289           2111ASHAVE,LUBBOCK                                 NaN
# 290        1211GROVERAVE,LUBBOCK                                 NaN
# 291         1408TEXASAVE,LUBBOCK                                 NaN
# 292          702TEXASAVE,LUBBOCK                                 NaN
# 293          820TEXASAVE,LUBBOCK                                 NaN
# 294    1618BUDDYHOLLYAVE,LUBBOCK                                 NaN
# 295       1804ATLANTAAVE,LUBBOCK                                 NaN
# 296        1505ALCOVEAVE,LUBBOCK                                 NaN
# 297    910CAMBRIDGEAVE,WOLFFORTH                                 NaN
# 298    910CAMBRIDGEAVE,WOLFFORTH                                 NaN
# 299          2007DATEAVE,LUBBOCK                                 NaN
# 300   232GENOAAVE,UNIT#B,LUBBOCK                                 NaN
# 301           2205ASHAVE,LUBBOCK                                 NaN
# 302       2123KIRKSEYAVE,LUBBOCK                                 NaN
# 303  1205BUCKINGHAMAVE,WOLFFORTH                                 NaN
# 304          2101DATEAVE,LUBBOCK                                 NaN
# 305         1310TEXASAVE,LUBBOCK                                 NaN
# 306    1508LANCELOTAVE,WOLFFORTH                                 NaN
# 307         2413CEDARAVE,LUBBOCK                                 NaN
# 308         1216TEXASAVE,LUBBOCK                                 NaN
# 309   1511CHURCHILLAVE,WOLFFORTH                                 NaN
# 310         1912INLERAVE,LUBBOCK                                 NaN
# 311          1022IOLAAVE,LUBBOCK                                 NaN
# 312          2110DATEAVE,LUBBOCK                                 NaN
# 313     224BUDDYHOLLYAVE,LUBBOCK                                 NaN
# 314         1917TEXASAVE,LUBBOCK                                 NaN
# 315         2314BIRCHAVE,LUBBOCK                                 NaN
# 316         1408TEXASAVE,LUBBOCK                                 NaN
# 317         2608INLERAVE,LUBBOCK                                 NaN
# 318           2001ASHAVE,LUBBOCK                                 NaN
# 319        1812BANGORAVE,LUBBOCK                                 NaN
# 320          318BEECHAVE,LUBBOCK                                 NaN
# 321      2407ABERDEENAVE,LUBBOCK                                 NaN
# 322       1003IRONTONAVE,LUBBOCK                                 NaN
# 323        3209KELSEYAVE,LUBBOCK                                 NaN
# 324   1519CHURCHILLAVE,WOLFFORTH                                 NaN
# 325       1021IRONTONAVE,LUBBOCK                                 NaN
# 326         2308BIRCHAVE,LUBBOCK                                 NaN
# 327       1802ATLANTAAVE,LUBBOCK                                 NaN
# 328       1802ATLANTAAVE,LUBBOCK                                 NaN
# 329       1802ATLANTAAVE,LUBBOCK                                 NaN
# 330       1802ATLANTAAVE,LUBBOCK                                 NaN
# 331   1504CHURCHILLAVE,WOLFFORTH                                 NaN
# 332        1305MOBILEAVE,LUBBOCK                                 NaN
# 333         2413CEDARAVE,LUBBOCK                                 NaN
# 334       1317BRYANAVE,WOLFFORTH                                 NaN
# 335       1009IRONTONAVE,LUBBOCK                                 NaN
# 336           190623RDST,LUBBOCK                                 NaN
# 337           200723RDST,LUBBOCK                                 NaN
# 338           262723RDST,LUBBOCK                                 NaN
# 339           221023RDST,LUBBOCK                                 NaN
# 340           270523RDST,LUBBOCK                                 NaN
# ...
# 374           15.00       79403.0                   48,435             37
# 375           10.44       79403.0                   48,435             38
# 376             NaN       79416.0                   52,861              3
# 377            3.00       79423.0                  293,997              8
# 378             NaN       79403.0                  176,208             17
# 379            0.98       79403.0                  176,208             18
# 380            6.50       79403.0                  284,059             33
# 381             NaN       79311.0                  335,728             35
#
#                         keywords_1945
# 0           2407, 22, ND, ST, LUBBOCK
# 1           2808, 28, TH, ST, LUBBOCK
# 2           2316, 31, ST, ST, LUBBOCK
# 3           1913, 27, TH, ST, LUBBOCK
# 4           2102, 15, TH, ST, LUBBOCK
# 5           2306, 29, TH, ST, LUBBOCK
# 6           2212, 60, TH, ST, LUBBOCK
# 7           2905, 20, TH, ST, LUBBOCK
# 8           1523, 27, TH, ST, LUBBOCK
# 9           2011, 88, TH, ST, LUBBOCK
# 10          3005, 22, ND, ST, LUBBOCK
# 11          1914, 16, TH, ST, LUBBOCK
# 12          1912, 16, TH, ST, LUBBOCK
# 13          1918, 61, ST, ST, LUBBOCK
# 14          1622, 10, TH, ST, LUBBOCK
# 15          2215, 60, TH, ST, LUBBOCK
# 16          1515, 29, TH, ST, LUBBOCK
# 17          2222, 17, TH, ST, LUBBOCK
# 18          2608, 24, TH, ST, LUBBOCK
# 19          2019, 17, TH, ST, LUBBOCK
# 20          2101, 27, TH, ST, LUBBOCK
# 21          2428, 26, TH, ST, LUBBOCK
# 22          2107, 15, TH, ST, LUBBOCK
# 23          2117, 62, ND, ST, LUBBOCK
# 24          2408, 13, TH, ST, LUBBOCK
# 25          2119, 18, TH, ST, LUBBOCK
# 26          2408, 13, TH, ST, LUBBOCK
# 27          1720, 24, TH, ST, LUBBOCK
# 28          1906, 15, TH, ST, LUBBOCK
# 29          2124, 20, TH, ST, LUBBOCK
# 30          2211, 17, TH, ST, LUBBOCK
# 31          2613, 21, ST, ST, LUBBOCK
# 32          1909, 25, TH, ST, LUBBOCK
# 33          2701, 21, ST, ST, LUBBOCK
# 34          2701, 21, ST, ST, LUBBOCK
# 35          2701, 21, ST, ST, LUBBOCK
# 36          1438, 78, TH, ST, LUBBOCK
# 37          1909, 29, TH, ST, LUBBOCK
# 38          1305, 30, TH, ST, LUBBOCK
# 39          1320, 16, TH, ST, LUBBOCK
# 40          1513, 31, ST, ST, LUBBOCK
# 41          2138, 19, TH, ST, LUBBOCK
# 42          2220, 19, TH, ST, LUBBOCK
# 43          2815, 26, TH, ST, LUBBOCK
# 44          1315, 25, TH, ST, LUBBOCK
# 45          1322, 25, TH, ST, LUBBOCK
# 46          1310, 28, TH, ST, LUBBOCK
# 47          1906, 94, TH, ST, LUBBOCK
# 48          1619, 39, TH, ST, LUBBOCK
# 49          2101, 16, TH, ST, LUBBOCK
# 50          2803, 27, TH, ST, LUBBOCK
# 51          2211, 14, TH, ST, LUBBOCK
# 52          2701, 29, TH, ST, LUBBOCK
# 53          2203, 29, TH, ST, LUBBOCK
# 54          3117, 21, ST, ST, LUBBOCK
# 55          2412, 21, ST, ST, LUBBOCK
# 56          2219, 96, TH, ST, LUBBOCK
# 57          2401, 29, TH, ST, LUBBOCK
# 58          2406, 32, ND, ST, LUBBOCK
# 59          1519, 28, TH, ST, LUBBOCK
# 60          2303, 28, TH, ST, LUBBOCK
# 61          2117, 30, TH, ST, LUBBOCK
# 62          2203, 25, TH, ST, LUBBOCK
# 63          2121, 30, TH, ST, LUBBOCK
# 64          2205, 25, TH, ST, LUBBOCK
# 65          2205, 25, TH, ST, LUBBOCK
# 66          1305, 27, TH, ST, LUBBOCK
# 67          2014, 17, TH, ST, LUBBOCK
# 68          1524, 27, TH, ST, LUBBOCK
# 69          1617, 19, TH, ST, LUBBOCK
# 70          1918, 20, TH, ST, LUBBOCK
# 71          1506, 25, TH, ST, LUBBOCK
# 72          2410, 32, ND, ST, LUBBOCK
# 73          1121, 31, ST, ST, LUBBOCK
# 74          1923, 16, TH, ST, LUBBOCK
# 75          1923, 16, TH, ST, LUBBOCK
# 76          1518, 30, TH, ST, LUBBOCK
# 77          1709, 24, TH, ST, LUBBOCK
# 78          3104, 22, ND, ST, LUBBOCK
# 79          2422, 29, TH, ST, LUBBOCK
# 80          1517, 27, TH, ST, LUBBOCK
# 81          2316, 30, TH, ST, LUBBOCK
# 82          2404, 31, ST, ST, LUBBOCK
# 83          1924, 16, TH, ST, LUBBOCK
# 84          1924, 16, TH, ST, LUBBOCK
# 85          1303, 26, TH, ST, LUBBOCK
# 86          2202, 17, TH, ST, LUBBOCK
# 87          2630, 24, TH, ST, LUBBOCK
# 88          2423, 32, ND, ST, LUBBOCK
# 89          1925, 21, ST, ST, LUBBOCK
# 90          2019, 16, TH, ST, LUBBOCK
# 91          2432, 22, ND, ST, LUBBOCK
# 92          2516, 29, TH, ST, LUBBOCK
# 93          1513, 26, TH, ST, LUBBOCK
# 94          2508, 26, TH, ST, LUBBOCK
# 95          2511, 28, TH, ST, LUBBOCK
# 96          2322, 90, TH, ST, LUBBOCK
# 97          2511, 22, ND, ST, LUBBOCK
# 98          2626, 21, ST, ST, LUBBOCK
# 99          1411, 24, TH, ST, LUBBOCK
# 100         1312, 26, TH, ST, LUBBOCK
# 101         1308, 26, TH, ST, LUBBOCK
# 102         2613, 22, ND, ST, LUBBOCK
# 103         2206, 16, TH, ST, LUBBOCK
# 104         1822, 79, TH, ST, LUBBOCK
# 105         2801, 30, TH, ST, LUBBOCK
# 106         1511, 27, TH, ST, LUBBOCK
# 107         1811, 13, TH, ST, LUBBOCK
# 108         2122, 25, TH, ST, LUBBOCK
# 109         1918, 18, TH, ST, LUBBOCK
# 110         2314, 16, TH, ST, LUBBOCK
# 111         2627, 21, ST, ST, LUBBOCK
# 112         1919, 99, TH, ST, LUBBOCK
# 113         2522, 21, ST, ST, LUBBOCK
# 114         1407, 24, TH, ST, LUBBOCK
# 115         1910, 81, ST, ST, LUBBOCK
# 116         2801, 28, TH, ST, LUBBOCK
# 117         1920, 81, ST, ST, LUBBOCK
# 118         1521, 24, TH, ST, LUBBOCK
# 119         1521, 24, TH, ST, LUBBOCK
# 120         1505, 22, ND, ST, LUBBOCK
# 121         2412, 26, TH, ST, LUBBOCK
# 122         2706, 22, ND, ST, LUBBOCK
# 123         2017, 16, TH, ST, LUBBOCK
# 124         1508, 28, TH, ST, LUBBOCK
# 125         2810, 22, ND, ST, LUBBOCK
# 126         2814, 20, TH, ST, LUBBOCK
# 127         2010, 31, ST, ST, LUBBOCK
# 128         2010, 31, ST, ST, LUBBOCK
# 129         2311, 88, TH, ST, LUBBOCK
# 130         2220, 20, TH, ST, LUBBOCK
# 131         2117, 29, TH, ST, LUBBOCK
# 132         2826, 24, TH, ST, LUBBOCK
# 133         2514, 25, TH, ST, LUBBOCK
# 134         2423, 21, ST, ST, LUBBOCK
# 135         2623, 21, ST, ST, LUBBOCK
# 136         2820, 24, TH, ST, LUBBOCK
# 137         2115, 20, TH, ST, LUBBOCK
# 138         2115, 20, TH, ST, LUBBOCK
# 139         2709, 30, TH, ST, LUBBOCK
# 140         1502, 27, TH, ST, LUBBOCK
# 141         2001, 27, TH, ST, LUBBOCK
# 142         2705, 30, TH, ST, LUBBOCK
# 143         2322, 78, TH, ST, LUBBOCK
# 144         2211, 25, TH, ST, LUBBOCK
# 145         2006, 27, TH, ST, LUBBOCK
# 146         2010, 27, TH, ST, LUBBOCK
# 147         1512, 26, TH, ST, LUBBOCK
# 148         2102, 30, TH, ST, LUBBOCK
# 149         1313, 27, TH, ST, LUBBOCK
# 150         2422, 27, TH, ST, LUBBOCK
# 151         2008, 25, TH, ST, LUBBOCK
# 152         2008, 25, TH, ST, LUBBOCK
# 153         1625, 68, TH, ST, LUBBOCK
# 154         3311, 20, TH, ST, LUBBOCK
# 155         2317, 17, TH, ST, LUBBOCK
# 156         1801, 13, TH, ST, LUBBOCK
# 157         3218, 21, ST, ST, LUBBOCK
# 158         1503, 25, TH, ST, LUBBOCK
# 159         2115, 14, TH, ST, LUBBOCK
# 160          2318, 80, TH, ST, LUBBOC
# 161         2103, 22, ND, ST, LUBBOCK
# 162         2611, 22, ND, ST, LUBBOCK
# 163         1921, 24, TH, ST, LUBBOCK
# 164         2311, 29, TH, ST, LUBBOCK
# 165         2311, 20, TH, ST, LUBBOCK
# 166         2422, 21, ST, ST, LUBBOCK
# 167         1906, 27, TH, ST, LUBBOCK
# 168         2302, 20, TH, ST, LUBBOCK
# 169         2302, 20, TH, ST, LUBBOCK
# 170         1911, 26, TH, ST, LUBBOCK
# 171         1618, 17, TH, ST, LUBBOCK
# 172         1619, 17, TH, ST, LUBBOCK
# 173         2123, 26, TH, ST, LUBBOCK
# 174         2509, 21, ST, ST, LUBBOCK
# 175         2309, 21, ST, ST, LUBBOCK
# 176         1509, 32, ND, ST, LUBBOCK
# 177         1922, 24, TH, ST, LUBBOCK
# 178         3214, 21, ST, ST, LUBBOCK
# 179         2206, 15, TH, ST, LUBBOCK
# 180         2115, 31, ST, ST, LUBBOCK
# 181         2016, 15, TH, ST, LUBBOCK
# 182         2520, 20, TH, ST, LUBBOCK
# 183         2436, 28, TH, ST, LUBBOCK
# 184         2106, 31, ST, ST, LUBBOCK
# 185         2515, 24, TH, ST, LUBBOCK
# 186         2305, 38, TH, ST, LUBBOCK
# 187         1215, 13, TH, ST, LUBBOCK
# 188         2016, 15, TH, ST, LUBBOCK
# 189         2016, 15, TH, ST, LUBBOCK
# 190         1715, 21, ST, ST, LUBBOCK
# 191         2712, 30, TH, ST, LUBBOCK
# 192         2712, 30, TH, ST, LUBBOCK
# 193         1906, 25, TH, ST, LUBBOCK
# 194         2116, 22, ND, ST, LUBBOCK
# 195         2116, 22, ND, ST, LUBBOCK
# 196         2115, 10, TH, ST, LUBBOCK
# 197         2312, 20, TH, ST, LUBBOCK
# 198         2114, 27, TH, ST, LUBBOCK
# 199         2021, 15, TH, ST, LUBBOCK
# 200         3022, 20, TH, ST, LUBBOCK
# 201         2221, 27, TH, ST, LUBBOCK
# 202         2103, 20, TH, ST, LUBBOCK
# 203         2514, 20, TH, ST, LUBBOCK
# 204         2606, 30, TH, ST, LUBBOCK
# 205         2606, 30, TH, ST, LUBBOCK
# 206         1515, 13, TH, ST, LUBBOCK
# 207         1309, 26, TH, ST, LUBBOCK
# 208         2436, 21, ST, ST, LUBBOCK
# 209         1611, 22, ND, ST, LUBBOCK
# 210         3311, 22, ND, ST, LUBBOCK
# 211         2313, 30, TH, ST, LUBBOCK
# 212         2313, 30, TH, ST, LUBBOCK
# 213         1619, 70, TH, ST, LUBBOCK
# 214         1101, 13, TH, ST, LUBBOCK
# 215      2808, E, 16, TH, ST, LUBBOCK
# 216      2019, E, 47, TH, ST, LUBBOCK
# 217      2015, E, 14, TH, ST, LUBBOCK
# 218      2208, E, 16, TH, ST, LUBBOCK
# 219      2421, E, 30, TH, ST, LUBBOCK
# 220    1601, N, 15, TH, ST, WOLFFORTH
# 221      2417, E, 28, TH, ST, LUBBOCK
# 222      2417, E, 28, TH, ST, LUBBOCK
# 223             1502, AVE, J, LUBBOCK
# 224             2006, AVE, K, LUBBOCK
# 225             1915, AVE, M, LUBBOCK
# 226             1925, AVE, P, LUBBOCK
# 227             1814, AVE, Q, LUBBOCK
# 228             2201, AVE, J, LUBBOCK
# 229             1916, AVE, M, LUBBOCK
# 230             1302, AVE, E, LUBBOCK
# 231             1312, AVE, J, LUBBOCK
# 232             1312, AVE, J, LUBBOCK
# 233             1509, AVE, K, LUBBOCK
# 234             1908, AVE, R, LUBBOCK
# 235             1716, AVE, E, LUBBOCK
# 236             2108, AVE, P, LUBBOCK
# 237             1948, AVE, N, LUBBOCK
# 238             2113, AVE, M, LUBBOCK
# 239             1511, AVE, O, LUBBOCK
# 240             2007, AVE, J, LUBBOCK
# 241             1917, AVE, O, LUBBOCK
# 242             2601, AVE, K, LUBBOCK
# 243             1927, AVE, N, LUBBOCK
# 244             1314, AVE, K, LUBBOCK
# 245             1212, AVE, J, LUBBOCK
# 246             1002, AVE, F, LUBBOCK
# 247             1608, AVE, N, LUBBOCK
# 248             1309, AVE, L, LUBBOCK
# 249             1313, AVE, J, LUBBOCK
# 250             1810, AVE, M, LUBBOCK
# 251             1220, AVE, K, LUBBOCK
# 252             1220, AVE, K, LUBBOCK
# 253             1806, AVE, R, LUBBOCK
# 254             1806, AVE, R, LUBBOCK
# 255             2013, AVE, J, LUBBOCK
# 256              903, AVE, K, LUBBOCK
# 257              809, AVE, G, LUBBOCK
# 258              912, AVE, B, LUBBOCK
# 259              918, AVE, J, LUBBOCK
# 260              812, AVE, G, LUBBOCK
# 261              808, AVE, G, LUBBOCK
# 262        2216, E, MAIN, ST, LUBBOCK
# 263        2221, E, MAIN, ST, LUBBOCK
# 264        1519, E, MAIN, ST, LUBBOCK
# 265     1710, N, ORWICH, AVE, LUBBOCK
# 266       419, N, OLIVE, AVE, LUBBOCK
# 267         2205, E, LM, AVE, LUBBOCK
# 268   809, N, FRANKFORD, AVE, LUBBOCK
# 269       408, N, XENIA, AVE, LUBBOCK
# 270       1209, E, LM, AVE, WOLFFORTH
# 271      1913, N, GENOA, AVE, LUBBOCK
# 272     814, N, BELMONT, AVE, LUBBOCK
# 273          602, E, LM, AVE, LUBBOCK
# 274      612, N, BANGOR, AVE, LUBBOCK
# 275    1304, N, QUINTON, AVE, LUBBOCK
# 276    1304, N, QUINTON, AVE, LUBBOCK
# 277    1304, N, QUINTON, AVE, LUBBOCK
# 278     708, N, CHICAGO, AVE, LUBBOCK
# 279     708, N, CHICAGO, AVE, LUBBOCK
# 280      1712, N, GENOA, AVE, LUBBOCK
# 281     1701, N, ORWICH, AVE, LUBBOCK
# 282      1912, N, GENOA, AVE, LUBBOCK
# 283   602, N, ENGLEWOOD, AVE, LUBBOCK
# 284       524, N, DOVER, AVE, LUBBOCK
# 285     503, N, CHICAGO, AVE, LUBBOCK
# 286   702, N, ENGLEWOOD, AVE, LUBBOCK
# 287      902, N, BANGOR, AVE, LUBBOCK
# 288     417, BUDDYHOLLY, AVE, LUBBOCK
# 289           2111, ASH, AVE, LUBBOCK
# 290        1211, GROVER, AVE, LUBBOCK
# 291         1408, TEXAS, AVE, LUBBOCK
# 292          702, TEXAS, AVE, LUBBOCK
# 293          820, TEXAS, AVE, LUBBOCK
# 294    1618, BUDDYHOLLY, AVE, LUBBOCK
# 295       1804, ATLANTA, AVE, LUBBOCK
# 296        1505, ALCOVE, AVE, LUBBOCK
# 297    910, CAMBRIDGE, AVE, WOLFFORTH
# 298    910, CAMBRIDGE, AVE, WOLFFORTH
# 299          2007, DATE, AVE, LUBBOCK
# 300             232, GENOA, AVE, UNIT
# 301           2205, ASH, AVE, LUBBOCK
# 302       2123, KIRKSEY, AVE, LUBBOCK
# 303  1205, BUCKINGHAM, AVE, WOLFFORTH
# 304          2101, DATE, AVE, LUBBOCK
# 305         1310, TEXAS, AVE, LUBBOCK
# 306    1508, LANCELOT, AVE, WOLFFORTH
# 307         2413, CEDAR, AVE, LUBBOCK
# 308         1216, TEXAS, AVE, LUBBOCK
# 309   1511, CHURCHILL, AVE, WOLFFORTH
# 310         1912, INLER, AVE, LUBBOCK
# 311          1022, IOLA, AVE, LUBBOCK
# 312          2110, DATE, AVE, LUBBOCK
# 313     224, BUDDYHOLLY, AVE, LUBBOCK
# 314         1917, TEXAS, AVE, LUBBOCK
# 315         2314, BIRCH, AVE, LUBBOCK
# 316         1408, TEXAS, AVE, LUBBOCK
# 317         2608, INLER, AVE, LUBBOCK
# 318           2001, ASH, AVE, LUBBOCK
# 319        1812, BANGOR, AVE, LUBBOCK
# 320          318, BEECH, AVE, LUBBOCK
# 321      2407, ABERDEEN, AVE, LUBBOCK
# 322       1003, IRONTON, AVE, LUBBOCK
# 323        3209, KELSEY, AVE, LUBBOCK
# 324   1519, CHURCHILL, AVE, WOLFFORTH
# 325       1021, IRONTON, AVE, LUBBOCK
# 326         2308, BIRCH, AVE, LUBBOCK
# 327       1802, ATLANTA, AVE, LUBBOCK
# 328       1802, ATLANTA, AVE, LUBBOCK
# 329       1802, ATLANTA, AVE, LUBBOCK
# 330       1802, ATLANTA, AVE, LUBBOCK
# 331   1504, CHURCHILL, AVE, WOLFFORTH
# 332        1305, MOBILE, AVE, LUBBOCK
# 333         2413, CEDAR, AVE, LUBBOCK
# 334       1317, BRYAN, AVE, WOLFFORTH
# 335       1009, IRONTON, AVE, LUBBOCK
# 336         1906, 23, RD, ST, LUBBOCK
# 337         2007, 23, RD, ST, LUBBOCK
# 338         2627, 23, RD, ST, LUBBOCK
# 339         2210, 23, RD, ST, LUBBOCK
# 340         2705, 23, RD, ST, LUBBOCK
# 341         1515, 23, RD, ST, LUBBOCK
# 342         1314, 53, RD, ST, LUBBOCK
# 343         2221, 93, RD, ST, LUBBOCK
# 344         2221, 23, RD, ST, LUBBOCK
# 345         2426, 23, RD, ST, LUBBOCK
# 346         2426, 23, RD, ST, LUBBOCK
# 347         2426, 23, RD, ST, LUBBOCK
# 348         2612, 23, RD, ST, LUBBOCK
# 349         2423, 33, RD, ST, LUBBOCK
# 350        2321, 102, ND, ST, LUBBOCK
# 351        1917, 100, TH, ST, LUBBOCK
# 352        2124, 135, TH, ST, LUBBOCK
# 353        2014, 100, TH, ST, LUBBOCK
# 354        2213, 100, TH, ST, LUBBOCK
# 355        2122, 101, ST, ST, LUBBOCK
# 356           2308, MAIN, ST, LUBBOCK
# 357           2308, MAIN, ST, LUBBOCK
# 358           1111, MAIN, ST, LUBBOCK
# 359           1221, MAIN, ST, LUBBOCK
# 360           2321, MAIN, ST, LUBBOCK
# 361           604, N, AVE, Q, LUBBOCK
# 362          1821, N, AVE, A, LUBBOCK
# 363           324, N, AVE, T, LUBBOCK
# 364        2010, E, BROADWAY, LUBBOCK
# 365        3105, HARVARD, ST, LUBBOCK
# 366    1120, E, URSULINE, ST, LUBBOCK
# 367        1619, ERSKINE, ST, LUBBOCK
# 368    1506, E, URSULINE, ST, LUBBOCK
# 369       1005, W, FISHER, ST, SLATON
# 370        1508, ERSKINE, ST, LUBBOCK
# 371    1317, E, STANFORD, ST, LUBBOCK
# 372    1317, E, STANFORD, ST, LUBBOCK
# 373            207, BROADWAY, LUBBOCK
# 374        1526, E, BROADWAY, LUBBOCK
# 375        1526, E, BROADWAY, LUBBOCK
# 376        1420, N, CR, 1300, LUBBOCK
# 377           1631, CR, 7340, LUBBOCK
# 378        1711, E, CR, 5400, LUBBOCK
# 379        1711, E, CR, 5400, LUBBOCK
# 380        2007, E, FM, 1294, LUBBOCK
# 381          2419, FM, 597, ABERNATHY

# %%
df1945_updated['ADDRESS_1945'] = df1945_updated['ADDRESS_1945'].str.replace(r'\blub\b', 'LUBBOCK', case=False, regex=True)
df1945_updated['ADDRESS_1945'] = df1945_updated['ADDRESS_1945'].str.replace(r'\bBx\b', 'BOX', case=False, regex=True)

# %% [markdown]
# #### Apply the `add_space_before_suffix()`

# %%
df1945_updated["ADDRESS_1945"] = df1945_updated["ADDRESS_1945"].apply(add_space_before_suffix)

# %% [markdown]
# #### Process Non-Empty addresses from 1945 dataframe

# %%
def process_nonempty_addresses(dfc, dfn=None):

    # Filter out rows where ADDRESS_1945 is NaN, None, or undesired strings, and directly work on a copy to avoid SettingWithCopyWarning
    valid_addresses = dfc['ADDRESS_1945'].apply(lambda x: x not in [None, 'nan', '"', '""','"""','""""','" "',',']) & dfc['ADDRESS_1945'].notna()
    valid_rows = dfc[valid_addresses].copy()  # Use .copy() here

    # If there are no valid addresses to process, just return the original dataframes
    if valid_rows.empty:
        return dfc, dfn if dfn is not None else pd.DataFrame()

    # Process the ADDRESS_1945 column: split by commas or spaces, then join with ', '
    valid_rows['keywords_1945'] = valid_rows['ADDRESS_1945'].apply(lambda address: ', '.join(address.replace(',', ' ').split()))

    # Add the 'oldindex_1945' column to keep track of the original index
    valid_rows['oldindex_1945'] = valid_rows.index

    # Prepare dfn (either append to it or create a new one)
    if dfn is not None:
        # When appending, it's safe as dfn is being explicitly modified
        dfn_updated = pd.concat([dfn, valid_rows], ignore_index=True)
    else:
        dfn_updated = valid_rows

    # Remove processed rows from the original dfc
    dfc_updated = dfc.drop(valid_rows.index).reset_index(drop=True)

    return dfc_updated, dfn_updated

# %% [markdown]
# #### Apply the function that processes the non-empty addresses

# %%
df1945_updated, dfn1945_updated = process_nonempty_addresses(df1945_updated, dfn1945_updated)

# %% [markdown]
# #### The abbreviations and their full forms

# %%
# Define the abbreviations and their full forms
abbreviations = {
    r'\bbwy\b': 'BROADWAY',
    r'\brt\b': 'ROUTE',
    r'\bave\b': 'AVENUE',
    r'\bbld\b': 'BUILDING'
}

# Replace abbreviations with their full forms (while keeping the abbreviation)
for abbr, full in abbreviations.items():
    dfn1945_updated['keywords_1945'] = dfn1945_updated['keywords_1945'].str.replace(abbr, lambda m: f"{m.group(0)}, {full}", flags=re.IGNORECASE, regex=True)

# %% [markdown]
# #### Remove the Addresses that dont have any alphabet or number in them

# %%
df1945 = dfn1945_updated

# %%
df1945 = remove_rows_without_alphabets_or_numbers(df1945, 'ADDRESS_1945')

# %% [markdown]
# #### Split the addresses

# %%
# Apply the function to the DataFrame
df1945 = split_keywords_vectorized(df1945, 'keywords_1945')

# %% [markdown]
# #### Rename column

# %%
df1945 = df1945.copy()
df1945.rename(columns={"numerical_keywords": "NK_1945", "alphabetical_short_keywords": "ASK_1945","alphabetical_long_keywords": "ALK_1945" }, inplace=True)

# %% [markdown]
# #### Delete a column

# %%
df1945.drop('oldindex_1945', axis=1, inplace=True)

# %% [markdown]
# ## Preprocessing done df1945
# ---

# %% [markdown]
# ## Pre-Process 1975

# %% [markdown]
# #### Remove the Addresses that dont have any alphabet in them

# %%
df1975 = remove_rows_without_alphabets_or_numbers(df1975, 'ADDRESS_1975')

# %% [markdown]
# #### Add spacing before the suffix

# %%
df1975["ADDRESS_1975"] = df1975["ADDRESS_1975"].apply(add_space_before_suffix)

# %% [markdown]
# #### Add a keywords column to 1975 dataframe

# %%
# Function to process address and city/town columns and combine them into keywords
def process_address_and_city(addresses, cities):
    # Split addresses and cities by space, comma, and period
    split_addresses = addresses.str.split('[ ,.]')
    split_cities = cities.fillna('').str.split('[ ,.]')

    # Combine the split parts from both columns
    combined = split_addresses + split_cities

    # Remove empty strings from lists and join the elements into comma-separated strings
    keywords = combined.apply(lambda lst: ','.join(filter(None, lst)))

    return keywords

# Apply the function to create the 'keywords_1975' column
df1975['keywords_1975'] = process_address_and_city(df1975['ADDRESS_1975'], df1975['ORIGINAL GRANTEE CITY OR TOWN_1975'])

# %% [markdown]
# #### Split the addresses

# %%
df1975 = split_keywords_vectorized(df1975, 'keywords_1975')

# %% [markdown]
# #### Rename the column

# %%
df1975 = df1975.copy()
df1975.rename(columns={"numerical_keywords": "NK_1975", "alphabetical_short_keywords": "ASK_1975","alphabetical_long_keywords": "ALK_1975" }, inplace=True)

# %% [markdown]
# ## Preprocessing done df1975
# ---

# %% [markdown]
# ## Pre-Process 1985

# %% [markdown]
# #### Remove the Addresses that dont have any alphabet in them

# %%
df1985 = remove_rows_without_alphabets_or_numbers(df1985, 'ADDRESS_1985')

# %% [markdown]
# #### convert the zip codes to respective city names

# %%
# List of ZIP codes (replace this list with your ZIP codes)
zip_codes = list(df1985["zip code_1985"].unique())

# Initialize the SearchEngine
search = SearchEngine()

# Function to convert ZIP codes to a dictionary with city names
def zip_to_city_dict(zip_codes):
    zip_city_dict = {}
    for zip_code in zip_codes:
        if zip_code is not None and zip_code != 'nan':
            result = search.by_zipcode(zip_code)
            zip_city_dict[zip_code] = result.major_city if result else 'Unknown'
        else:
            zip_city_dict[zip_code] = 'Unknown'
    return zip_city_dict

# Convert ZIP codes to city names in a dictionary
zip_city_dict = zip_to_city_dict(zip_codes)
# Out:
# Download /root/.uszipcode/simple_db.sqlite from https://github.com/MacHu-GWU/uszipcode-project/releases/download/1.0.1.db/simple_db.sqlite ...
#   1.00 MB downloaded ...
#   2.00 MB downloaded ...
#   3.00 MB downloaded ...
#   4.00 MB downloaded ...
#   5.00 MB downloaded ...
#   6.00 MB downloaded ...
#   7.00 MB downloaded ...
#   8.00 MB downloaded ...
#   9.00 MB downloaded ...
#   10.00 MB downloaded ...
#   11.00 MB downloaded ...
#   Complete!

# %% [markdown]
# #### Add space before suffix

# %%
df1985["ADDRESS_1985"] = df1985["ADDRESS_1985"].apply(add_space_before_suffix)

# %% [markdown]
# #### Add keywords column to 1985 data frame

# %%
# Function to split addresses and replace ZIP codes with city names
def process_addresses_and_zip_codes(addresses, zip_codes, zip_city_dict):
    # Split addresses by space, comma, and period
    split_addresses = addresses.str.split('[ ,.]')

    # Vectorized operation to map ZIP codes to city names
    city_names = zip_codes.map(zip_city_dict).fillna('Unknown')

    # Combine split addresses and city names into keywords
    keywords = split_addresses + city_names.apply(lambda x: [x])

    # Flatten the lists into strings
    keywords_str = keywords.apply(lambda x: ', '.join([word for word in x if word]))

    return keywords_str

# Apply the function to the DataFrame
df1985['keywords_1985'] = process_addresses_and_zip_codes(df1985['ADDRESS_1985'], df1985['zip code_1985'], zip_city_dict)

# %% [markdown]
# #### Splitting keywords

# %%
df1985 = split_keywords_vectorized(df1985, 'keywords_1985')

# %% [markdown]
# #### Rename the column

# %%
df1985 = df1985.copy()
df1985.rename(columns={"numerical_keywords": "NK_1985", "alphabetical_short_keywords": "ASK_1985","alphabetical_long_keywords": "ALK_1985" }, inplace=True)

# %% [markdown]
# ## Preprocessing done df1985
# ---

# %% [markdown]
# ## Check all the preprocessed dataframes

# %%
df1945.head()
# Out:
#   People_1945 document number_1945 PARCEL NUMBER_1945        ADDRESS_1945  \
# 0       Aoxue                  NaN                NaN  240722NDST,LUBBOCK
# 1         NaN                  NaN                NaN  280828THST,LUBBOCK
# 2         NaN                  NaN                NaN  231631STST,LUBBOCK
# 3         NaN                  NaN                NaN  191327THST,LUBBOCK
# 4         NaN                  NaN                NaN  210215THST,LUBBOCK
#
#   ORIGINAL GRANTEE CITY OR TOWN_1945 DESIGNATE HOMESTEAD_1945  \
# 0                                NaN                      NaN
# 1                                NaN                      NaN
# 2                                NaN                      NaN
# 3                                NaN                      NaN
# 4                                NaN                      NaN
#
#   VALUE OF CITY PROPERTY_1945 VALUE OF PERSONAL PROPERTY_1945 STATE TAX_1945  \
# 0                        2700                             NaN            NaN
# 1                        1800                             NaN            NaN
# 2                        2200                             NaN            NaN
# 3                        1500                             NaN            NaN
# 4                        2000                             NaN            NaN
#
#   COUNTY TAX_1945  Total Tax_1945  Zipcode_1945 2022 Assessed Value_1945  \
# 0             NaN            13.5       79411.0                  153,148
# 1             NaN             9.0       79410.0                  153,602
# 2             NaN            11.0       79411.0                   96,701
# 3             NaN             7.5       79411.0                  104,699
# 4             NaN             NaN       79401.0                    96597
#
#                keywords_1945   NK_1945 ASK_1945 ALK_1945
# 0  2407, 22, ND, ST, LUBBOCK  2407, 22   ND, ST  LUBBOCK
# 1  2808, 28, TH, ST, LUBBOCK  2808, 28   TH, ST  LUBBOCK
# 2  2316, 31, ST, ST, LUBBOCK  2316, 31   ST, ST  LUBBOCK
# 3  1913, 27, TH, ST, LUBBOCK  1913, 27   TH, ST  LUBBOCK
# 4  2102, 15, TH, ST, LUBBOCK  2102, 15   TH, ST  LUBBOCK

# %%
df1975.head()
# Out:
#   People_1975 document number_1975    ADDRESS_1975  \
# 0       Ainur          ScanPro1022   1917 10 TH ST
# 1         NaN                  NaN   2820 62 ND ST
# 2         NaN                  NaN   3110 39 TH ST
# 3         NaN                  NaN  2704 B COLGATE
# 4         NaN                  NaN   3412 29 TH ST
#
#   ORIGINAL GRANTEE CITY OR TOWN_1975 ACERES RENDERED_1975  \
# 0                            LUBBOCK                  NaN
# 1                            LUBBOCK                  NaN
# 2                            LUBBOCK                  NaN
# 3                            LUBBOCK                  NaN
# 4                            LUBBOCK                  NaN
#
#   VALUE DOLLARS (STATE VALUE)_1975 DESIGNATE HOMESTEAD_1975  \
# 0                              NaN                     2340
# 1                              750                     3000
# 2                             4650                     3000
# 3                              NaN                      520
# 4                              610                     3000
#
#   VALUE OF CITY PROPERTY (TOTAL COUNTY VALUE)_1975  \
# 0                                              340
# 1                                             3750
# 2                                             7650
# 3                                              520
# 4                                             3610
#
#   VALUE OF PERSONAL PROPERTY_1975 TOTAL VALUE FOR CONTY TAX_1975  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#   STATE TAX_1975  COUNTY TAX_1975 DISTRICT SCHOOL_1975  \
# 0              0              0.0                  NaN
# 1             90            585.0                  NaN
# 2            558           3627.0                  NaN
# 3              0              0.0                  NaN
# 4             73            476.0                  NaN
#
#   TAX TOTAL (INCLUDING HOSPITAL AND WATER TAXES)_1975  Unnamed: 15_1975  \
# 0                                                  0                NaN
# 1                                               1276                NaN
# 2                                               7906                NaN
# 3                                                  0                NaN
# 4                                               1036                NaN
#
#   Unnamed: 25_1975           keywords_1975   NK_1975 ASK_1975  \
# 0              NaN   1917,10,TH,ST,LUBBOCK  1917, 10   TH, ST
# 1              NaN   2820,62,ND,ST,LUBBOCK  2820, 62   ND, ST
# 2              NaN   3110,39,TH,ST,LUBBOCK  3110, 39   TH, ST
# 3              NaN  2704,B,COLGATE,LUBBOCK      2704        B
# 4              NaN   3412,29,TH,ST,LUBBOCK  3412, 29   TH, ST
#
#            ALK_1975
# 0           LUBBOCK
# 1           LUBBOCK
# 2           LUBBOCK
# 3  COLGATE, LUBBOCK
# 4           LUBBOCK

# %%
df1985.head()
# Out:
#   People_1985 Folder Name_1985 document number_1985    ADDRESS_1985  \
# 0         NaN              NaN                 none   0402 40 TH ST
# 1         NaN              NaN                  NaN    407 38 TH ST
# 2         NaN              NaN                  NaN   0501 35 TH ST
# 3         NaN              NaN                  NaN   0507 35 TH ST
# 4         NaN              NaN                  NaN  515 E 35 TH ST
#
#   zip code_1985 Area_1985         Roll Seq_1985 LAND _1985 BLD-VAL_1985  \
# 0         79404       NaN                   NaN       2600          NaN
# 1         79404       205  1505 AVE D BLK 1 L 4       2580        10580
# 2         79404       206                  3059       1250         7790
# 3         79404       206                  3062       1340        11830
# 4         79404       206                  3066       1190        10910
#
#   SPEC_FEAT_1985  ... LBB SCHOOL_1985  LBB CITY_1985 L C H D_1985  \
# 0            NaN  ...          104.44          67.38        12.98
# 1            100  ...           76.82          79.56        15.32
# 2            NaN  ...           37.57          54.24        10.44
# 3            100  ...           76.91          79.62        15.33
# 4            500  ...          117.18           75.6        14.55
#
#   COUNTY.1_1985 GROSS TAX_1985 Unnamed: 20_1985                keywords_1985  \
# 0         18.79         204.35              NaN    0402, 40, TH, ST, Lubbock
# 1         22.16         194.79              NaN     407, 38, TH, ST, Lubbock
# 2         15.11         117.99              NaN    0501, 35, TH, ST, Lubbock
# 3         22.17         194.96              NaN    0507, 35, TH, ST, Lubbock
# 4         21.05         229.26              NaN  515, E, 35, TH, ST, Lubbock
#
#     NK_1985   ASK_1985 ALK_1985
# 0  0402, 40     TH, ST  Lubbock
# 1   407, 38     TH, ST  Lubbock
# 2  0501, 35     TH, ST  Lubbock
# 3  0507, 35     TH, ST  Lubbock
# 4   515, 35  E, TH, ST  Lubbock
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Matching Try 01

# %%
df1945[["keywords_1945",	"NK_1945",	"ASK_1945",	"ALK_1945"]].head()
# Out:
#                keywords_1945   NK_1945 ASK_1945 ALK_1945
# 0  2407, 22, ND, ST, LUBBOCK  2407, 22   ND, ST  LUBBOCK
# 1  2808, 28, TH, ST, LUBBOCK  2808, 28   TH, ST  LUBBOCK
# 2  2316, 31, ST, ST, LUBBOCK  2316, 31   ST, ST  LUBBOCK
# 3  1913, 27, TH, ST, LUBBOCK  1913, 27   TH, ST  LUBBOCK
# 4  2102, 15, TH, ST, LUBBOCK  2102, 15   TH, ST  LUBBOCK

# %%
df1975[["keywords_1975",	"NK_1975",	"ASK_1975",	"ALK_1975"]].head()
# Out:
#             keywords_1975   NK_1975 ASK_1975          ALK_1975
# 0   1917,10,TH,ST,LUBBOCK  1917, 10   TH, ST           LUBBOCK
# 1   2820,62,ND,ST,LUBBOCK  2820, 62   ND, ST           LUBBOCK
# 2   3110,39,TH,ST,LUBBOCK  3110, 39   TH, ST           LUBBOCK
# 3  2704,B,COLGATE,LUBBOCK      2704        B  COLGATE, LUBBOCK
# 4   3412,29,TH,ST,LUBBOCK  3412, 29   TH, ST           LUBBOCK

# %%
df1985[["keywords_1985",	"NK_1985",	"ASK_1985",	"ALK_1985"]].head()
# Out:
#                  keywords_1985   NK_1985   ASK_1985 ALK_1985
# 0    0402, 40, TH, ST, Lubbock  0402, 40     TH, ST  Lubbock
# 1     407, 38, TH, ST, Lubbock   407, 38     TH, ST  Lubbock
# 2    0501, 35, TH, ST, Lubbock  0501, 35     TH, ST  Lubbock
# 3    0507, 35, TH, ST, Lubbock  0507, 35     TH, ST  Lubbock
# 4  515, E, 35, TH, ST, Lubbock   515, 35  E, TH, ST  Lubbock

# %%
import pandas as pd

def prepare_vectorized_matching(df_base, df_targets, base_year, target_years):
    """
    Perform vectorized address matching based on specified criteria.

    :param df_base: DataFrame containing base addresses and keywords.
    :param df_targets: List of DataFrames for comparison.
    :param base_year: The base year for df_base.
    :param target_years: List of years corresponding to each DataFrame in df_targets.
    """
    # Container for match results
    match_results = []

    # Iterate through target DataFrames for comparison
    for df_target, year in zip(df_targets, target_years):
        # Vectorized extraction and comparison of NK, ASK, ALK from base to target DataFrame
        # Assuming NK, ASK, ALK are separated by comma and space ", "
        # This approach might need adjustment based on actual data structure

        # Step 1: Numerical Keyword (NK) Matching
        # Convert NK columns to sets for easier comparison
        df_base[f'NK_{base_year}_set'] = df_base[f'NK_{base_year}'].str.split(', ').apply(set)
        df_target[f'NK_{year}_set'] = df_target[f'NK_{year}'].str.split(', ').apply(set)

        # Calculate intersection size of NK sets between base and target
        nk_match = df_base[f'NK_{base_year}_set'].apply(lambda x: df_target[f'NK_{year}_set'].apply(lambda y: len(x & y)))

        # Define NK match criteria based on base NK count
        nk_criteria = df_base[f'NK_{base_year}_set'].apply(len).apply(lambda x: 2 if x >= 2 else 1)

        # Step 2: ALK Matching
        # Split ALK keywords for easier comparison, consider non-empty values only
        df_base['ALK_matches'] = df_base[f'ALK_{base_year}'].str.lower().str.split(', ').apply(lambda alk: df_target[f'ALK_{year}'].str.lower().str.contains('|'.join(alk) if alk != [''] else '^\b$', regex=True))

        # Aggregate match information
        for index, row in df_base.iterrows():
            nk_match_count = nk_match.loc[index]
            alk_matches = row['ALK_matches']

            # Identify rows in target DataFrame that meet NK and ALK criteria
            valid_nk_indices = nk_match_count[nk_match_count >= nk_criteria.loc[index]].index
            valid_alk_indices = alk_matches[alk_matches].index

            # Intersection of NK and ALK match indices for final matching
            final_match_indices = valid_nk_indices.intersection(valid_alk_indices)

            if not final_match_indices.empty:
                match_info = {
                    'Base_Index': index,
                    'Base_Year': base_year,
                    'Target_Year': year,
                    'Matched_Indices': final_match_indices.tolist(),
                    'Match_Count': len(final_match_indices)
                }
                match_results.append(match_info)
                print(f"Match found: Base Year {base_year}, Target Year {year}, Base Index {index}, Match Count: {len(final_match_indices)}")

    return pd.DataFrame(match_results)

# %%
df_base = df1945  # Example base DataFrame
df_targets = [df1975, df1985]  # List of target comparison DataFrames
base_year = 1945
target_years = [1975, 1985]

match_results_df = prepare_vectorized_matching(df_base, df_targets, base_year, target_years)

# %%
match_results_df.head()

# %%
matches_df.set_index(['Index_1945', 'Year', 'Matched_Index'], inplace=True)

# %%
writ
